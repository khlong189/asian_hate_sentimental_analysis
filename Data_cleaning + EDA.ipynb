# %% [markdown]
# # Objective:
#
# - Find frequency of hashtags.
# - Explore `date`, `language`, and `text`.
# - Remove languages that have low frequency.
# - Change `date` type to `datetime`.
# - Clean `text` for sentimental analysis, tokenization, and remove stopwords (eng).

# %% [markdown]
# # Set up:

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/NLP project /data')

# %% [markdown]
# # Libraries:

# %%
import pandas as pd
import plotly.express as px
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import defaultdict

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv('tweets.csv')

# %% [markdown]
# # Exploratory Data Analysis:

# %% [markdown]
# ## Language

# %%
df['language'].value_counts()
# Out:
# en     11072
# qht     1808
# qme     1356
# ja       401
# es       350
# und      319
# hi       203
# zh        73
# in        69
# ko        68
# pt        52
# et        45
# it        42
# tl        37
# th        36
# fr        26
# fa        18
# vi        17
# de        11
# tr        11
# ca        10
# pl        10
# ml         9
# nl         9
# ru         8
# da         7
# mr         5
# ar         4
# pa         4
# sv         4
# ht         4
# te         3
# cs         3
# fi         2
# sl         2
# lv         2
# ta         2
# or         1
# ne         1
# ro         1
# eu         1
# hu         1
# uk         1
# cy         1
# is         1
# lt         1
# no         1
# Name: language, dtype: int64

# %%
fig = px.histogram(df, x="language",
                   title = ("Tweet languages histogram"),
                   text_auto=True).update_layout(bargap=0.2)

fig.update_xaxes(tickangle=-90)                   
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6fd79651-3cea-4d9a-962b-18fd817c0dd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd79651-3cea-4d9a-962b-18fd817c0dd4")) {                    Plotly.newPlot(                        "6fd79651-3cea-4d9a-962b-18fd817c0dd4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"language=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"texttemplate":"%{value}","x":["en","en","en","qht","en","qht","qht","en","qht","qme","en","ja","en","en","und","en","en","en","qht","en","en","en","en","qht","en","en","es","en","en","qht","qht","en","en","en","en","en","qht","en","en","en","qht","en","en","en","en","qme","en","en","en","en","en","qht","qht","en","en","en","en","en","en","en","en","und","en","en","qme","en","en","qme","en","it","en","en","en","en","en","en","es","qht","qht","en","qme","en","en","en","en","en","en","en","es","qht","en","qht","ja","en","qht","qht","en","en","en","qme","en","en","en","en","en","ko","qht","ko","en","qme","en","en","en","qht","en","qht","qht","en","en","en","en","en","en","en","en","en","es","qme","en","qht","qht","qme","qme","en","en","en","qht","en","en","hi","qme","en","en","qht","qht","en","en","en","en","en","ja","en","en","en","qht","qht","qht","en","en","en","en","en","en","pl","en","en","en","en","en","qht","qht","en","en","en","qme","qme","qht","qht","en","en","en","en","qme","en","en","en","en","en","en","en","en","en","en","en","en","en","en","en","pl","qht","qht","en","en","en","en","en","en","en","zh","en","en","zh","en","zh","en","en","en","en","in","en","en","en","en","in","en","qht","qht","en","qme","en","hi","en","en","en","qme","en","en","en","en","en","qht","en","zh","en","en","en","en","en","en","en","en","zh","en","en","en","en","en","en","hi","es","en","qht","qht","fr","en","is","in","en
%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["#stopaapihate","#chinesevirus","#stopasianhate","#stopasianhatecrimes","#aapi","#china","#blacklivesmatter","#covid19","#respond2racism","#aapiheritagemonth","#wuhanvirus","#omicron","#xijinping","#getvaccinated","#coronavirus","#freetibet","#letsgobrandon","#ccp","#trumpwon2020","#electionfraud","#chairmanbiden","#peoplesrepublicofamerica","#heilcovid","#welcometo1984","#whoisjohngalt","#womensrights","#lgbtqia","#covid","#indigenous","#chinese","#transrightsarehumanrights","#btsatthewhitehouse","#asianamerican","#blm","#us","#racism","#bannon","#standwithukraine","#republicansaredestroyingamerica","#yanlimeng","#veryasian","#india","#usa","#freehk","#bts","#wuhan","#un","#\u90ed\u6587\u8d35","#apahm","#transrights","#republicansaretheproblem","#sanfrancisco","#nyc","#asian","#chinaliedpeopledied","#chinavirus","#indigenouspeoples","#eu","#jimmykimmelracist","#genocidegames","#getboosted","#theyellowwhistle","#votebluetosavedemocracy","#who","#asianamericans","#acttochange","#covid_19","#asians","#atlantashooting","#solidarity"],"xaxis":"x","y":[4957,3087,2837,1681,559,516,410,406,391,242,237,178,176,163,161,157,155,154,146,146,146,146,146,146,146,142,139,136,130,129,122,118,112,108,104,103,103,100,100,96,92,89,87,87,87,81,81,81,79,78,77,74,73,71,71,68,68,67,66,65,62,61,60,59,57,56,55,54,53,51],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %% [markdown]
# ## Date:

# %%
df['date'] = df['date'].astype("datetime64")

# %%
df.sort_values(by='date').head(10)
# Out:
#                      date             tweet_id  \
# 16111 2021-11-25 02:17:18  1463693245997731843
# 16110 2021-11-25 02:18:15  1463693483034566658
# 16109 2021-11-25 03:36:36  1463713202336776192
# 16107 2021-11-25 05:56:04  1463748301111496705
# 16106 2021-11-25 06:12:25  1463752416365408259
# 16105 2021-11-25 06:26:02  1463755839999602693
# 16103 2021-11-25 06:52:38  1463762536138821637
# 16102 2021-11-25 08:03:21  1463780333334065160
# 16101 2021-11-25 08:20:27  1463784636123811847
# 16100 2021-11-25 08:22:44  1463785210646974465
#
#                                                     text       user_name  \
# 16111  @globaltimesnews Commitment to spread #Chinese...   KarnekarAnand
# 16110  Why is this happening to #USA?\nIt is happenin...     HKChandnani
# 16109  @globaltimesnews #China is the enemy of entire...      vivek_nana
# 16107  @globaltimesnews No. these are majorly affecte...      hrishi4778
# 16106  In #Philadelphia today 😞\nSeeing racial slurs ...       bulbulnyc
# 16105  @globaltimesnews The problem with China is tha...      3170Anupam
# 16103  Perfect shit colour for shitty army of #CCP wa...  BigDaddy310631
# 16102                #COVID #ChineseVirus is still there       anmol0707
# 16101  Considering the raise in #ChineseVirus cases i...       anmol0707
# 16100  Country after country dependent on Pfizer, Mod...      Sh07509514
#
#        reply_count  retweet_count  like_count language
# 16111            0              0           0       en
# 16110            0              0           0       en
# 16109            0              0           1       en
# 16107            0              0           1       en
# 16106            0              0           0       en
# 16105            0              0           5       en
# 16103            0              0           0       en
# 16102            0              0           0       en
# 16101            0              0           0       en
# 16100            0              0           2       en

# %%
# Tweets date histogram

dates_count = df['date'].dt.date.value_counts().sort_index()


fig = px.line(df, 
        x = dates_count.index, y = dates_count,
        title = ("Tweet counts over time on the topic of Asian hate speech"),
        labels={'x': 'Timeline', 
                'y':'Frequency'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="156628aa-6663-45c6-8047-71a962687dfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("156628aa-6663-45c6-8047-71a962687dfb")) {                    Plotly.newPlot(                        "156628aa-6663-45c6-8047-71a962687dfb",                        [{"hovertemplate":"Timeline=%{x}<br>Frequency=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-11-25","2021-11-26","2021-11-27","2021-11-28","2021-11-29","2021-11-30","2021-12-01","2021-12-02","2021-12-03","2021-12-04","2021-12-05","2021-12-06","2021-12-07","2021-12-08","2021-12-09","2021-12-10","2021-12-11","2021-12-12","2021-12-13","2021-12-14","2021-12-15","2021-12-16","2021-12-17","2021-12-18","2021-12-19","2021-12-20","2021-12-21","2021-12-22","2021-12-23","2021-12-24","2021-12-25","2021-12-26","2021-12-27","2021-12-28","2021-12-29","2021-12-30","2021-12-31","2022-01-01","2022-01-02","2022-01-03","2022-01-04","2022-01-05","2022-01-06","2022-01-07","2022-01-08","2022-01-09","2022-01-10","2022-01-11","2022-01-12","2022-01-13","2022-01-14","2022-01-15","2022-01-16","2022-01-17","2022-01-18","2022-01-19","2022-01-20","2022-01-21","2022-01-22","2022-01-23","2022-01-24","2022-01-25","2022-01-26","2022-01-27","2022-01-28","2022-01-29","2022-01-30","2022-01-31","2022-02-01","2022-02-02","2022-02-03","2022-02-04","2022-02-05","2022-02-06","2022-02-07","2022-02-08","2022-02-09","2022-02-10","2022-02-11","2022-02-12","2022-02-13","2022-02-14","2022-02-15","2022-02-16","2022-02-17","2022-02-18","2022-02-19","2022-02-20","2022-02-21","2022-02-22","2022-02-23","2022-02-24","2022-02-25","2022-02-26","2022-02-27","2022-02-28","2022-03-01","2022-03-02","2022-03-03","2022-03-04","2022-03-05","2022-03-06","2022-03-07","2022-03-08","2022-03-09","2022-03-10","2022-03-11","2022-03-12","2022-03-13","2022-03-14","2022-03-15","2022-03-16","2022-03-17","2022-03-18","2022-03-19","2022-03-20","2022-03-21","2022-03-22","2022-03-23","2022-03-24","2022-03-25","2022-03-26","2022-03-27","2022-03-28","2022-03-29","2022-03-30","2022-03-31","2022-04-01","2022-04-02","2022-04-03","2022-04-04","2022-04-05","2022-04-06","2022-04-07","2022-04-08","2022-04-09","2022-04-10","2022-04-11","2022-04-12","2022-04-13","2022-04-14","2022-04-15","2022-04-16","2022-04-17","2022-04-18","2022-04-19","2022-04-20","2022-04-21","2022-04-22","2022-04-23","2022-04-24","2022-04-25","2022-04-26","2022-04-27","2022-04-28","2022-04-29","2022-04-30","2022-05-01","2022-05-02","2022-05-03","2022-05-04","2022-05-05","2022-05-06","2022-05-07","2022-05-08","2022-05-09","2022-05-10","2022-05-11","2022-05-12","2022-05-13","2022-05-14","2022-05-15","2022-05-16","2022-05-17","2022-05-18","2022-05-19","2022-05-20","2022-05-21","2022-05-22","2022-05-23","2022-05-24","2022-05-25","2022-05-26","2022-05-27","2022-05-28","2022-05-29","2022-05-30","2022-05-31","2022-06-01","2022-06-02","2022-06-03","2022-06-04","2022-06-05","2022-06-06","2022-06-07","2022-06-08","2022-06-09","2022-06-10","2022-06-11","2022-06-12","2022-06-13","2022-06-14","2022-06-15","2022-06-16","2022-06-17","2022-06-18","2022-06-19","2022-06-20","2022-06-21","2022-06-22","2022-06-23","2022-06-24","2022-06-25","2022-06-26","2022-06-27","2022-06-28","2022-06-29","2022-06-30","2022-07-01","2022-07-02","2022-07-03","2022-07-04","2022-07-05","2022-07-06","2022-07-07","2022-07-08","2022-07-09","2022-07-10","2022-07-11","2022-07-12","2022-07-13","2022-07-14","2022-07-15","2022-07-16","2022-07-17","2022-07-18","2022-07-19","2022-07-20","2022-07-21","2022-07-22","2022-07-23","2022-07-24","2022-07-25","2022-07-26","2022-07-27","2022-07-28","2022-07-29","2022-07-30","2022-07 ...

# %% [markdown]
# ## Text:

# %%
stemmer = PorterStemmer() #stemming

# %%
df = df.drop_duplicates('text')

# %%
stop_words = set(stopwords.words("english"))

# %%
def tweet_cleaning(text):
    text = text.lower() #lower cases for sentimental analysis
    text = re.sub(r'https?:\/\/\S+','',text) #remove hyperlinks
    text = re.sub(r'#','',text) #remove hashtag symbols
    text = re.sub(r'@[a-z0-9]+','',text) #remove @mentions
    text = text = re.sub(r'[^^a-zA-Z0-9\s]','',text) #remove punctuations/special characters
    text = re.sub(r'(RT|rt|FAV|fav|VIA|via)', '', text) #remove all retweets, faves reference in content
    text_tokens = word_tokenize(text)
    text = [w for w in text_tokens if not w in stop_words] #keep words in tokenization, remove stopwords
    return " ".join(text)

# %%
df['text'] = df['text'].apply(tweet_cleaning)

# %%
df['text'].iloc[1]
# Out:
# 'horrifying paly grew bloomington amp large number foreign students university made feel child town welcoming multiculturalism horrifying problem everywhere country stopasianhate stopaapihate'

# %%
df.head(10)
# Out:
#                   date             tweet_id  \
# 0  2023-01-15 16:19:28  1614658536038105088
# 1  2023-01-15 15:52:49  1614651830130118659
# 2  2023-01-15 15:32:53  1614646811352002560
# 4  2023-01-15 14:38:58  1614633243533545473
# 7  2023-01-15 10:09:35  1614565451274809349
# 10 2023-01-15 06:11:32  1614505546257960961
# 12 2023-01-15 05:00:00  1614487542769795073
# 13 2023-01-15 04:02:16  1614473015227547649
# 15 2023-01-15 00:54:43  1614425814560567296
# 16 2023-01-15 00:23:59  1614418082230931457
#
#                                                  text       user_name  \
# 0   hate crime needs charged suchstories like nati...      speedkitty
# 1   horrifying paly grew bloomington amp large num...     ellen_adair
# 2   another prime example media using antiasian am...    AllLeahWrote
# 4   according cou documents white woman told polic...         queenkv
# 7   msm quiet asian hate billie davis 56 admitted ...   FirstThemNEWS
# 10  thank sharing lest think antiasian hate decrea...     dorisfchang
# 12  hate asian american pacific islander aapi popu...  Respond2Racism
# 13  stories media afraid discuss cover ask represe...  AsianSocialNet
# 15  thanks hosting screening inspiring look linsan...        PhilTing
# 16  good night tweeps getvaccinated getboosted sta...     kitchen5203
#
#     reply_count  retweet_count  like_count language
# 0             0              0           0       en
# 1             0              0           8       en
# 2             1              0          11       en
# 4             0              0           2       en
# 7             7             50          78       en
# 10            0              0           0       en
# 12            0              0           1       en
# 13            0              1           2       en
# 15            1              1           4       en
# 16            0              0           0       en

# %% [markdown]
# # Exporting data to .CSV file:

# %%
# df.to_csv('/content/drive/MyDrive/NLP project /data/cleaned_tweets.csv', encoding='utf-8', index=False)
